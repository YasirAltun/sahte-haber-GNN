# %%
import torch
vers = torch.__version__
print("Torch vers: ", vers)


#pip install torch_geometric
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git


import torch_geometric
# Out:
# Torch vers:  2.2.1+cu121
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %% [markdown]
# Kaynak ve Ham veri : [https://github.com/KaiDMML/FakeNewsNet](https://github.com/KaiDMML/FakeNewsNet)

# %%
import torch
vers = torch.__version__
print("Torch vers: ", vers)


#pip install torch_geometric
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git


import torch_geometric


from torch_geometric.datasets import UPFD
train_data = UPFD(root=".", name="gossipcop", feature="content", split="train")
test_data = UPFD(root=".", name="gossipcop", feature="content", split="test")
print("Train Samples: ", len(train_data))
print("Test Samples: ", len(test_data))



sample_id=1
train_data[sample_id].edge_index



# !pip install networkx
import networkx as nx

# From PyG utils
def to_networkx(data, node_attrs=None, edge_attrs=None, to_undirected=False,
                remove_self_loops=False):
    if to_undirected:
        G = nx.Graph()
    else:
        G = nx.DiGraph()
    G.add_nodes_from(range(data.num_nodes))
    node_attrs, edge_attrs = node_attrs or [], edge_attrs or []
    values = {}
    for key, item in data(*(node_attrs + edge_attrs)):
        if torch.is_tensor(item):
            values[key] = item.squeeze().tolist()
        else:
            values[key] = item
        if isinstance(values[key], (list, tuple)) and len(values[key]) == 1:
            values[key] = item[0]
    for i, (u, v) in enumerate(data.edge_index.t().tolist()):
        if to_undirected and v > u:
            continue
        if remove_self_loops and u == v:
            continue
        G.add_edge(u, v)
        for key in edge_attrs:
            G[u][v][key] = values[key][i]
    for key in node_attrs:
        for i, feat_dict in G.nodes(data=True):
            feat_dict.update({key: values[key][i]})
    return G



# !pip install torch
import torch
nx.draw(to_networkx(train_data[sample_id]))
# Out:
# ...
# Extracting ./gossipcop/raw/data.zip
# Processing...
# Done!
# Train Samples:  1092
# Test Samples:  3826
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# ...

# %%
from torch_geometric.datasets import UPFD
train_data = UPFD(root=".", name="politifact", feature="content", split="train")
test_data = UPFD(root=".", name="politifact", feature="content", split="test")
print("Train Samples: ", len(train_data))
print("Test Samples: ", len(test_data))



sample_id=1
train_data[sample_id].edge_index



# !pip install networkx
import networkx as nx

# From PyG utils
def to_networkx(data, node_attrs=None, edge_attrs=None, to_undirected=False,
                remove_self_loops=False):
    if to_undirected:
        G = nx.Graph()
    else:
        G = nx.DiGraph()
    G.add_nodes_from(range(data.num_nodes))
    node_attrs, edge_attrs = node_attrs or [], edge_attrs or []
    values = {}
    for key, item in data(*(node_attrs + edge_attrs)):
        if torch.is_tensor(item):
            values[key] = item.squeeze().tolist()
        else:
            values[key] = item
        if isinstance(values[key], (list, tuple)) and len(values[key]) == 1:
            values[key] = item[0]
    for i, (u, v) in enumerate(data.edge_index.t().tolist()):
        if to_undirected and v > u:
            continue
        if remove_self_loops and u == v:
            continue
        G.add_edge(u, v)
        for key in edge_attrs:
            G[u][v][key] = values[key][i]
    for key in node_attrs:
        for i, feat_dict in G.nodes(data=True):
            feat_dict.update({key: values[key][i]})
    return G



# !pip install torch
import torch
nx.draw(to_networkx(train_data[sample_id]))
# Out:
# ...
# Extracting ./politifact/raw/data.zip
# Processing...
# Done!
# Train Samples:  62
# Test Samples:  221
# ...

# %%
import torch
vers = torch.__version__  # torch kütüphanesinin versiyonunu al ve vers değişkenine ata
print("Torch vers: ", vers)  # torch kütüphanesinin versiyonunu yazdır

# Torch Geometric kütüphanesini GitHub reposundan sessizce yükle
# !pip install -q git+https://github.com/rusty1s/pytorch_geometric.git

import torch_geometric  # torch_geometric kütüphanesini içe aktar

# UPFD veri setini eğitim ve test setleri olarak yükle
from torch_geometric.datasets import UPFD
train_data = UPFD(root=".", name="gossipcop", feature="content", split="train")  # Eğitim veri setini yükle
test_data = UPFD(root=".", name="gossipcop", feature="content", split="test")  # Test veri setini yükle
print("Train Samples: ", len(train_data))  # Eğitim örneklerinin sayısını yazdır
print("Test Samples: ", len(test_data))  # Test örneklerinin sayısını yazdır

sample_id=1  # Örnek ID'si olarak 1 kullan
train_data[sample_id].edge_index  # Verilen ID'ye sahip eğitim örneğinin kenar indekslerini al

# NetworkX kütüphanesini yükle
# !pip install networkx
import networkx as nx

# PyG'den bir grafik veri yapısını NetworkX grafik formatına dönüştürme fonksiyonu
def to_networkx(data, node_attrs=None, edge_attrs=None, to_undirected=False,
                remove_self_loops=False):  # Fonksiyon tanımı ve parametreleri
    if to_undirected:  # Eğer çift yönlü grafik yapmak isteniyorsa
        G = nx.Graph()  # Çift yönlü grafik oluştur
    else:
        G = nx.DiGraph()  # Tek yönlü grafik oluştur
    G.add_nodes_from(range(data.num_nodes))  # Düğümleri grafikte oluştur
    node_attrs, edge_attrs = node_attrs or [], edge_attrs or []  # Düğüm ve kenar özelliklerini ayarla
    values = {}
    for key, item in data(*(node_attrs + edge_attrs)):  # Özellikleri işle
        if torch.is_tensor(item):  # Eğer tensor ise
            values[key] = item.squeeze().tolist()  # Listeye çevir
        else:
            values[key] = item
        if isinstance(values[key], (list, tuple)) and len(values[key]) == 1:  # Eğer liste veya tuple tek elemanlıysa
            values[key] = item[0]
    for i, (u, v) in enumerate(data.edge_index.t().tolist()):  # Kenarları ve indekslerini işle
        if to_undirected and v > u:  # Çift yönlü ve düğüm sırası önemliyse atla
            continue
        if remove_self_loops and u == v:  # Kendi kendine döngü varsa atla
            continue
        G.add_edge(u, v)  # Kenarı grafiğe ekle
        for key in edge_attrs:  # Kenar özelliklerini ekle
            G[u][v][key] = values[key][i]
    for key in node_attrs:  # Düğüm özelliklerini ekle
        for i, feat_dict in G.nodes(data=True):
            feat_dict.update({key: values[key][i]})
    return G  # Oluşturulan grafik nesnesini döndür


nx.draw(to_networkx(train_data[sample_id]))  # Elde edilen grafik yapısını çizdir
# Out:
# Torch vers:  2.2.1+cu121
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Extracting ./gossipcop/raw/data.zip
# Processing...
# Done!
# Train Samples:  1092
# Test Samples:  3826
# ...
